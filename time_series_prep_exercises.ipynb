# %% [markdown]
# # Exercises

# %%
import pandas as pd
import matplotlib.pyplot as plt
from vega_datasets import data

# %%
store_items = pd.read_csv("whole_df.csv")

# %%
store_items
# Out:
#         Unnamed: 0 item_brand  item_id  \
# 0                0   Riceland        1
# 1                1   Riceland        1
# 2                2   Riceland        1
# 3                3   Riceland        1
# 4                4   Riceland        1
# ...            ...        ...      ...
# 912995      912995     Choice       50
# 912996      912996     Choice       50
# 912997      912997     Choice       50
# 912998      912998     Choice       50
# 912999      912999     Choice       50
#
#                                                 item_name  item_price  \
# 0                          Riceland American Jazmine Rice        0.84
# 1                          Riceland American Jazmine Rice        0.84
# 2                          Riceland American Jazmine Rice        0.84
# 3                          Riceland American Jazmine Rice        0.84
# 4                          Riceland American Jazmine Rice        0.84
# ...
